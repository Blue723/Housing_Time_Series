# %% [markdown]
# - the goal of the project is to determine which zipcode has the best prediction/model.
#
# - does the house price in a zipcode change significatnly over the period of time
#     -change over each year
#     -change over the entire observed years 2011-2017
#
# - how does each zipcode of that year compare to the average of all the zipcodes that year

# %% [markdown]
# 1. import dataframe
# 2. set index to date time
# 3. Compare Beginning and end of year prices
#   - change over each year
#   - change over the entire observed years 2011-2017
#   - how does each zipcode of that year compare to the average of all the zipcodes that year
# 4. Sarima
#   - predict 2017 and compare to actual data
#   - mean square error for each zipcode
#
#   - future predict 2018-2020
